# %% [markdown]
# ## API Data Retrieval and Storage: You are tasked with fetching data from an external REST API, storing it in a local SQLite database, and displaying the retrieved data. The API provides a list of books in JSON format with attributes like title, author, and publication year.

# %% [markdown]
# ## Importing Libraries

# %%
import requests
from bs4 import BeautifulSoup
import json
import sqlite3

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'
}

# Make GET request with custom headers
response = requests.get("https://www.goodreads.com/search?q=scifi&qid=", headers=headers).text

# %%
#print(response)

# %%
soup = BeautifulSoup(response, 'html.parser')

# %%
title = soup.find_all('a',class_ = 'bookTitle')
print(title)
# Out:
# [<a class="bookTitle" href="/book/show/60149138-the-ancient-code?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=1" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">The Ancient Code: A SciFi Adventure (The Ancient Secrets, #1)</span>
# </a>, <a class="bookTitle" href="/book/show/61097137-the-extinction-threat?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=2" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">THE EXTINCTION THREAT: A SciFi Adventure (The Ancient Secrets, #2)</span>
# </a>, <a class="bookTitle" href="/book/show/123251611-relic?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=3" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">RELIC: A SciFi Adventure</span>
# </a>, <a class="bookTitle" href="/book/show/62622391-the-ancestor-trap?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=4" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">THE ANCESTOR TRAP: A SciFi Adventure (The Ancient Secrets, #3)</span>
# </a>, <a class="bookTitle" href="/book/show/77571048-the-missing-link?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=5" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">THE MISSING LINK: A SciFi Adventure (The Ancient Secrets, #4)</span>
# </a>, <a class="bookTitle" href="/book/show/10967376-free-science-fiction-books-on-kindle?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=6" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Free Science Fiction Books On Kindle: Linked List of over 350 Free SciFi  Classic Stories And Early Fantasy Novels</span>
# </a>, <a class="bookTitle" href="/book/show/152385810-the-calypso-mystery?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=7" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">THE CALYPSO MYSTERY: A SciFi Adventure (The Ancient Secrets Book 5)</span>
# </a>, <a class="bookTitle" href="/book/show/38389729-primeval-origins?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=8" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">Primeval Origins : Paths of Anguish (Epic Fantasy / SciFi Book Series 1)</span>
# </a>, <a class="bookTitle" href="/book/show/202668238-ice?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=9" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">ICE: A SciFi Adventure</span>
# </a>, <a class="bookTitle" href="/book/show/197715187-the-keepers-of-secrets?from_search=true&amp;from_srp=true&amp;qid=xOtdgBxnPi&amp;rank=10" itemprop="url">
# <span aria-level="4" itemprop="name" role="heading">THE KEEPERS OF SECRETS: A SciFi Adventure (The Ancient Secrets Book 6)</span>
# </a>]

# %%
author_name = soup.find_all('a' , class_ = 'authorName')
print(author_name)
# Out:
# [<a class="authorName" href="https://www.goodreads.com/author/show/22159829.T_S_Falk?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">T.S. Falk</span></a>, <a class="authorName" href="https://www.goodreads.com/author/show/22159829.T_S_Falk?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">T.S. Falk</span></a>, <a class="authorName" href="https://www.goodreads.com/author/show/22159829.T_S_Falk?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">T.S. Falk</span></a>, <a class="authorName" href="https://www.goodreads.com/author/show/22159829.T_S_Falk?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">T.S. Falk</span></a>, <a class="authorName" href="https://www.goodreads.com/author/show/22159829.T_S_Falk?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">T.S. Falk</span></a>, <a class="authorName" href="https://www.goodreads.com/author/show/69252.Morris_Rosenthal?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">Morris Rosenthal</span></a>, <a class="authorName" href="https://www.goodreads.com/author/show/22159829.T_S_Falk?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">T.S. Falk</span></a>, <a class="authorName" href="https://www.goodreads.com/author/show/8132422.B_A_Vonsik?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">B.A. Vonsik</span></a>, <a class="authorName" href="https://www.goodreads.com/author/show/22159829.T_S_Falk?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">T.S. Falk</span></a>, <a class="authorName" href="https://www.goodreads.com/author/show/22159829.T_S_Falk?from_search=true&amp;from_srp=true" itemprop="url"><span itemprop="name">T.S. Falk</span></a>]

# %%
# Extract book titles
titles = [title.get_text(strip=True) for title in soup.find_all('a', class_='bookTitle')]

# Extract author names
authors = [author.get_text(strip=True) for author in soup.find_all('a', class_='authorName')]

# Combine titles and authors
book_info = [f"{title} by {author}" for title, author in zip(titles, authors)]

# Print combined book information
print("Combined Book Information:")
for info in book_info:
    print(info)
# Out:
# Combined Book Information:
# The Ancient Code: A SciFi Adventure (The Ancient Secrets, #1) by T.S. Falk
# THE EXTINCTION THREAT: A SciFi Adventure (The Ancient Secrets, #2) by T.S. Falk
# RELIC: A SciFi Adventure by T.S. Falk
# THE ANCESTOR TRAP: A SciFi Adventure (The Ancient Secrets, #3) by T.S. Falk
# THE MISSING LINK: A SciFi Adventure (The Ancient Secrets, #4) by T.S. Falk
# Free Science Fiction Books On Kindle: Linked List of over 350 Free SciFi  Classic Stories And Early Fantasy Novels by Morris Rosenthal
# THE CALYPSO MYSTERY: A SciFi Adventure (The Ancient Secrets Book 5) by T.S. Falk
# Primeval Origins : Paths of Anguish (Epic Fantasy / SciFi Book Series 1) by B.A. Vonsik
# ICE: A SciFi Adventure by T.S. Falk
# THE KEEPERS OF SECRETS: A SciFi Adventure (The Ancient Secrets Book 6) by T.S. Falk

# %% [markdown]
# ## Fetching and printing Data

# %%
base_url = "https://www.goodreads.com/search"
query_params = {
    "q": "scifi",
    "qid": "1VUDZBjhSt",
    "tab": "books"
}


num_pages = 5     # Number of pages to scrape

for page in range(1, num_pages + 1):
    query_params["page"] = page
    response = requests.get(base_url, params=query_params, headers=headers)
    
 
    soup = BeautifulSoup(response.content, "html.parser")
    titles = [title.get_text(strip=True) for title in soup.find_all('a', class_='bookTitle')]
    authors = [author.get_text(strip=True) for author in soup.find_all('a', class_='authorName')]
        
    print(f"Page {page}:")
    for title, author in zip(titles, authors):
        print(f"{title} by {author}")
# Out:
# Page 1:
# The Ancient Code: A SciFi Adventure (The Ancient Secrets, #1) by T.S. Falk
# THE EXTINCTION THREAT: A SciFi Adventure (The Ancient Secrets, #2) by T.S. Falk
# RELIC: A SciFi Adventure by T.S. Falk
# THE ANCESTOR TRAP: A SciFi Adventure (The Ancient Secrets, #3) by T.S. Falk
# THE MISSING LINK: A SciFi Adventure (The Ancient Secrets, #4) by T.S. Falk
# Free Science Fiction Books On Kindle: Linked List of over 350 Free SciFi  Classic Stories And Early Fantasy Novels by Morris Rosenthal
# THE CALYPSO MYSTERY: A SciFi Adventure (The Ancient Secrets Book 5) by T.S. Falk
# Primeval Origins : Paths of Anguish (Epic Fantasy / SciFi Book Series 1) by B.A. Vonsik
# ICE: A SciFi Adventure by T.S. Falk
# THE KEEPERS OF SECRETS: A SciFi Adventure (The Ancient Secrets Book 6) by T.S. Falk
# Page 2:
# Nova's Blade: A Young Adult Dystopian Cyberpunk by Will Scifi
# Nova's Blade: A Young Adult Dystopian by Will Scifi
# Defenders of the Rim: Beginnings (A Far Future SciFi Thriller, #1) by Randal Sloan
# The Arx: A Thriller/Scifi novel by Jay Allan Storey
# The Maker War: A scifi action-adventure novel for the whole family by D.M.C. Shaw
# THE APOCALYPSE SEQUENCE I: A SciFi Adventure (The Ancient Secrets Book 7) by T.S. Falk
# The Adventures of Kirk Rogers: Inside the Moon (The Kirk Rogers Series: Scifi • Action • Comedy Book 1) by C.J. Boyle
# 2022 SciFi Anthology (The Science Fiction Novelists, #2) by E.J. Runyon
# SciFi & Fantasy: Five Movie Length Tales From Aisle Seat Books by S.A. Gibson
# Election Day: A Horrifying Thriller by Claudia Blood
# Page 3:
# Starfighter Rising: An Epic SciFi Adventure (Starfighter Rising Series Book 1) by Daniel Seegmiller
# Stranded with the Alien: A SciFi Fated Mates Romance (Antasun's Alien Castaways Book 1) by Roxy Nash
# Zero: A prequel to the humorous scifi series by Simon Haynes
# 2023 SciFi Anthology (The Science Fiction Novelists, #3) by S.A. Gibson
# Rescuing Red (SciFi Fairytale Fusions #1) by David Booker
# Alien Song: A Royal Alien Romance (Scifi Alien Human Romance, #1) by Philip Cahill
# Claimed by Brothers: A Scifi Alien Romance (Over the Top Galactic Heroes Book 1) by Leann Ryans
# The Alien Prince's Captive (Scifi Alien Romance) by V.T. Bonds
# Worlds of Wonder: Collected SciFi Short Stories by Deiri Di
# Soren: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 1) by Kai Lesy
# Page 4:
# The First Men in the Moon by H.G. Wells
# Solar King: Uniting the Twelve Zodiacs - Taurus by Marco  Frazetta
# Loved Cyborg: A SciFi Cyborg Romance (Bound by Her Book 2) by Nellie C. Lind
# Shadow Corps Boxset 1-4: A Military SciFi Series by Justin Sloan
# Bride to the Brutal Beast: A SciFi Romance (Galactic Matchmakers Book 1) by Athena Storm
# Warhead: Origins: A Scifi Haremlit Fantasy Series (The Brother's Code Book 1) by Troy Maverick
# Taken to Sky: A SciFi Alien Romance (Xiveri Mates Book 9) by Elizabeth  Stephens
# THE APOCALYPSE SEQUENCE II: A SciFi Adventure (The Ancient Secrets Book 8) by T.S. Falk
# Defenders of the Rim: Badlands (A Far Future SciFi Thriller, #2) by Randal Sloan
# Eldorado: A Dystopian/Scifi Novel by Jay Allan Storey
# Page 5:
# Defenders of the Rim: Badlands (A Far Future SciFi Thriller, #2) by Randal Sloan
# Rathgar: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 2) by Taylor Neptune
# Sucaen: A SciFi Alien Warrior Romance (Ka'atari Warriors Book 5) by Jasper Thorne
# Spring Into SciFi: 2022 Edition by Kenzie Kelly
# Spring Into SciFi : 2023 Edition by Greg Eccleston
# Abducted By The Warrior Prince: A SciFi Alien Romance (Lunarian Warriors Book 1) by Alex Minns
# Terminus Project: Mars by Mark Bilsborough
# Retribution (Sector 64 #2) by Andrew M. Ferrell
# Brutal Alien Beasts: A Collection of Scifi Romances by Karl El-Koura
# Celestial Mates Complete Series Box Set (Books 6-10) (Alien SciFi Romance) by Alex Minns

# %% [markdown]
# ## Printing Data in Json Format

# %%
num_pages = 5

book_data = []

# Loop through each page to scrape book data
for page in range(1, num_pages + 1):
    query_params["page"] = page
    
    # Send a GET request to the Goodreads search page
    response = requests.get(base_url, params=query_params, headers=headers)
    
    # Check if the response is successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the response
        soup = BeautifulSoup(response.content, "html.parser")
        
        # Extract titles and authors from the page
        titles = [title.get_text(strip=True) for title in soup.find_all('a', class_='bookTitle')]
        authors = [author.get_text(strip=True) for author in soup.find_all('a', class_='authorName')]
        
        # Combine titles and authors into book_data list of dictionaries
        for title, author in zip(titles, authors):
            book_data.append({
                "title": title,
                "author": author
            })
    else:
        # Print an error message if the request fails
        print(f"Error fetching page {page}: {response.status_code}")

# Convert book_data to JSON format
json_data = json.dumps(book_data, indent=2)

# Print or save the JSON data
print(json_data)
# Out:
# [
#   {
#     "title": "The Ancient Code: A SciFi Adventure (The Ancient Secrets, #1)",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "THE EXTINCTION THREAT: A SciFi Adventure (The Ancient Secrets, #2)",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "RELIC: A SciFi Adventure",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "THE ANCESTOR TRAP: A SciFi Adventure (The Ancient Secrets, #3)",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "THE MISSING LINK: A SciFi Adventure (The Ancient Secrets, #4)",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "Free Science Fiction Books On Kindle: Linked List of over 350 Free SciFi  Classic Stories And Early Fantasy Novels",
#     "author": "Morris Rosenthal"
#   },
#   {
#     "title": "THE CALYPSO MYSTERY: A SciFi Adventure (The Ancient Secrets Book 5)",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "Primeval Origins : Paths of Anguish (Epic Fantasy / SciFi Book Series 1)",
#     "author": "B.A. Vonsik"
#   },
#   {
#     "title": "ICE: A SciFi Adventure",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "THE KEEPERS OF SECRETS: A SciFi Adventure (The Ancient Secrets Book 6)",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "Nova's Blade: A Young Adult Dystopian Cyberpunk",
#     "author": "Will Scifi"
#   },
#   {
#     "title": "Nova's Blade: A Young Adult Dystopian",
#     "author": "Will Scifi"
#   },
#   {
#     "title": "The Arx: A Thriller/Scifi novel",
#     "author": "Jay Allan Storey"
#   },
#   {
#     "title": "Defenders of the Rim: Beginnings (A Far Future SciFi Thriller, #1)",
#     "author": "Randal Sloan"
#   },
#   {
#     "title": "The Maker War: A scifi action-adventure novel for the whole family",
#     "author": "D.M.C. Shaw"
#   },
#   {
#     "title": "The Adventures of Kirk Rogers: Inside the Moon (The Kirk Rogers Series: Scifi \u2022 Action \u2022 Comedy Book 1)",
#     "author": "C.J. Boyle"
#   },
#   {
#     "title": "THE APOCALYPSE SEQUENCE I: A SciFi Adventure (The Ancient Secrets Book 7)",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "2022 SciFi Anthology (The Science Fiction Novelists, #2)",
#     "author": "E.J. Runyon"
#   },
#   {
#     "title": "Election Day: A Horrifying Thriller",
#     "author": "S.A. Gibson"
#   },
#   {
#     "title": "Stranded with the Alien: A SciFi Fated Mates Romance (Antasun's Alien Castaways Book 1)",
#     "author": "Claudia Blood"
#   },
#   {
#     "title": "Stranded with the Alien: A SciFi Fated Mates Romance (Antasun's Alien Castaways Book 1)",
#     "author": "Roxy Nash"
#   },
#   {
#     "title": "Starfighter Rising: An Epic SciFi Adventure (Starfighter Rising Series Book 1)",
#     "author": "Daniel Seegmiller"
#   },
#   {
#     "title": "Zero: A prequel to the humorous scifi series",
#     "author": "Simon Haynes"
#   },
#   {
#     "title": "2023 SciFi Anthology (The Science Fiction Novelists, #3)",
#     "author": "S.A. Gibson"
#   },
#   {
#     "title": "Rescuing Red (SciFi Fairytale Fusions #1)",
#     "author": "David Booker"
#   },
#   {
#     "title": "The Alien Prince's Captive (Scifi Alien Romance)",
#     "author": "Philip Cahill"
#   },
#   {
#     "title": "Soren: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 1)",
#     "author": "Leann Ryans"
#   },
#   {
#     "title": "Claimed by Brothers: A Scifi Alien Romance (Over the Top Galactic Heroes Book 1)",
#     "author": "V.T. Bonds"
#   },
#   {
#     "title": "Worlds of Wonder: Collected SciFi Short Stories",
#     "author": "Luna Hunter"
#   },
#   {
#     "title": "Alien Song: A Royal Alien Romance (Scifi Alien Human Romance, #1)",
#     "author": "Taylor Neptune"
#   },
#   {
#     "title": "The First Men in the Moon",
#     "author": "H.G. Wells"
#   },
#   {
#     "title": "Loved Cyborg: A SciFi Cyborg Romance (Bound by Her Book 2)",
#     "author": "Nellie C. Lind"
#   },
#   {
#     "title": "Solar King: Uniting the Twelve Zodiacs - Taurus",
#     "author": "Marco  Frazetta"
#   },
#   {
#     "title": "Taken to Sky: A SciFi Alien Romance (Xiveri Mates Book 9)",
#     "author": "Elizabeth  Stephens"
#   },
#   {
#     "title": "Shadow Corps Boxset 1-4: A Military SciFi Series",
#     "author": "Justin Sloan"
#   },
#   {
#     "title": "Bride to the Brutal Beast: A SciFi Romance (Galactic Matchmakers Book 1)",
#     "author": "Athena Storm"
#   },
#   {
#     "title": "Warhead: Origins: A Scifi Haremlit Fantasy Series (The Brother's Code Book 1)",
#     "author": "Troy Maverick"
#   },
#   {
#     "title": "THE APOCALYPSE SEQUENCE II: A SciFi Adventure (The Ancient Secrets Book 8)",
#     "author": "T.S. Falk"
#   },
#   {
#     "title": "Eldorado: A Dystopian/Scifi Novel",
#     "author": "Jay Allan Storey"
#   },
#   {
#     "title": "Defenders of the Rim: Badlands (A Far Future SciFi Thriller, #2)",
#     "author": "Randal Sloan"
#   },
#   {
#     "title": "PULSERIDER: A SciFi Adventure",
#     "author": "Lou Schreiber"
#   },
#   {
#     "title": "Rathgar: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 2)",
#     "author": "Taylor Neptune"
#   },
#   {
#     "title": "Sucaen: A SciFi Alien Warrior Romance (Ka'atari Warriors Book 5)",
#     "author": "Jasper Thorne"
#   },
#   {
#     "title": "Spring Into SciFi : 2023 Edition",
#     "author": "Kenzie Kelly"
#   },
#   {
#     "title": "Abducted By The Warrior Prince: A SciFi Alien Romance (Lunarian Warriors Book 1)",
#     "author": "Andrew M. Ferrell"
#   },
#   {
#     "title": "Spring Into SciFi: 2022 Edition",
#     "author": "Karl El-Koura"
#   },
#   {
#     "title": "Retribution (Sector 64 #2)",
#     "author": "Alex Minns"
#   },
#   {
#     "title": "Terminus Project: Mars",
#     "author": "Roxie Ray"
#   },
#   {
#     "title": "Celestial Mates Complete Series Box Set (Books 6-10) (Alien SciFi Romance)",
#     "author": "Greg Eccleston"
#   },
#   {
#     "title": "Alien Hunter's Prey: A SciFi Romance (Mates of the Baktu Book 1)",
#     "author": "Alex Minns"
#   }
# ]

# %% [markdown]
# ## Storing book data in database using sqlite3

# %%
json_data = json.dumps(book_data)

connection = sqlite3.connect('bookstore.db') 


cursor = connection.cursor()


cursor.execute('''CREATE TABLE IF NOT EXISTS books
                (id INTEGER PRIMARY KEY AUTOINCREMENT,
                title TEXT,
                author TEXT)''')

for book in book_data:
    cursor.execute('INSERT INTO books (title, author) VALUES (?, ?)', (book['title'], book['author']))


connection.commit()

cursor.close()
connection.close()

# %% [markdown]
# ## Printing data from bookstore DataBase

# %%
connection = sqlite3.connect('bookstore.db')
cursor = connection.cursor()

cursor.execute('SELECT * FROM books')

rows = cursor.fetchall()
for row in rows:
    print(row) 
cursor.close()
connection.close()
# Out:
# (1, "Nova's Blade: A Young Adult Dystopian", 'Will Scifi')
# (2, "Nova's Blade: A Young Adult Dystopian Cyberpunk", 'Will Scifi')
# (3, 'The Arx: A Thriller/Scifi novel', 'Jay Allan Storey')
# (4, 'Defenders of the Rim: Beginnings (A Far Future SciFi Thriller, #1)', 'Randal Sloan')
# (5, 'The Maker War: A scifi action-adventure novel for the whole family', 'D.M.C. Shaw')
# (6, 'The Adventures of Kirk Rogers: Inside the Moon (The Kirk Rogers Series: Scifi • Action • Comedy Book 1)', 'C.J. Boyle')
# (7, 'THE APOCALYPSE SEQUENCE I: A SciFi Adventure (The Ancient Secrets Book 7)', 'T.S. Falk')
# (8, '2022 SciFi Anthology (The Science Fiction Novelists, #2)', 'E.J. Runyon')
# (9, 'SciFi & Fantasy: Five Movie Length Tales From Aisle Seat Books', 'S.A. Gibson')
# (10, 'Election Day: A Horrifying Thriller', 'Claudia Blood')
# (11, 'Starfighter Rising: An Epic SciFi Adventure (Starfighter Rising Series Book 1)', 'Daniel Seegmiller')
# (12, 'SciFi & Fantasy: Five Movie Length Tales From Aisle Seat Books', 'Ed Gray')
# (13, '2023 SciFi Anthology (The Science Fiction Novelists, #3)', 'Kenan Brack')
# (14, 'Zero: A prequel to the humorous scifi series', 'Lee A. Matthias')
# (15, 'Rescuing Red (SciFi Fairytale Fusions #1)', 'S.A. Gibson')
# (16, 'Claimed by Brothers: A Scifi Alien Romance (Over the Top Galactic Heroes Book 1)', 'David Booker')
# (17, 'Soren: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 1)', 'Philip Cahill')
# (18, 'Alien Song: A Royal Alien Romance (Scifi Alien Human Romance, #1)', 'Simon Haynes')
# (19, 'Worlds of Wonder: Collected SciFi Short Stories', 'Leann Ryans')
# (20, "The Alien Prince's Captive (Scifi Alien Romance)", 'V.T. Bonds')
# (21, 'Solar King: Uniting the Twelve Zodiacs - Taurus', 'Marco  Frazetta')
# (22, 'The First Men in the Moon', 'H.G. Wells')
# (23, 'Loved Cyborg: A SciFi Cyborg Romance (Bound by Her Book 2)', 'Nellie C. Lind')
# (24, 'Shadow Corps Boxset 1-4: A Military SciFi Series', 'Justin Sloan')
# (25, 'Bride to the Brutal Beast: A SciFi Romance (Galactic Matchmakers Book 1)', 'Athena Storm')
# (26, "Warhead: Origins: A Scifi Haremlit Fantasy Series (The Brother's Code Book 1)", 'Troy Maverick')
# (27, 'Taken to Sky: A SciFi Alien Romance (Xiveri Mates Book 9)', 'Elizabeth  Stephens')
# (28, 'THE APOCALYPSE SEQUENCE II: A SciFi Adventure (The Ancient Secrets Book 8)', 'T.S. Falk')
# (29, 'PULSERIDER: A SciFi Adventure', 'Lou Schreiber')
# (30, 'Defenders of the Rim: Badlands (A Far Future SciFi Thriller, #2)', 'Randal Sloan')
# (31, 'PULSERIDER: A SciFi Adventure', 'Lou Schreiber')
# (32, 'Defenders of the Rim: Badlands (A Far Future SciFi Thriller, #2)', 'Randal Sloan')
# (33, 'Abducted By The Warrior Prince: A SciFi Alien Romance (Lunarian Warriors Book 1)', 'Roxie Ray')
# (34, 'Spring Into SciFi : 2023 Edition', 'Andrew M. Ferrell')
# (35, 'Spring Into SciFi: 2022 Edition', 'Karl El-Koura')
# (36, "Sucaen: A SciFi Alien Warrior Romance (Ka'atari Warriors Book 5)", 'Alex Minns')
# (37, 'Terminus Project: Mars', 'Greg Eccleston')
# (38, "Alien Hunter's Prey: A SciFi Romance (Mates of the Baktu Book 1)", 'Alex Minns')
# (39, 'Retribution (Sector 64 #2)', 'Mark Bilsborough')
# (40, 'Brutal Alien Beasts: A Collection of Scifi Romances', 'Kenzie Kelly')
# (41, 'The Ancient Code: A SciFi Adventure (The Ancient Secrets, #1)', 'T.S. Falk')
# (42, 'THE EXTINCTION THREAT: A SciFi Adventure (The Ancient Secrets, #2)', 'T.S. Falk')
# (43, 'RELIC: A SciFi Adventure', 'T.S. Falk')
# (44, 'THE ANCESTOR TRAP: A SciFi Adventure (The Ancient Secrets, #3)', 'T.S. Falk')
# (45, 'THE MISSING LINK: A SciFi Adventure (The Ancient Secrets, #4)', 'T.S. Falk')
# (46, 'Free Science Fiction Books On Kindle: Linked List of over 350 Free SciFi  Classic Stories And Early Fantasy Novels', 'Morris Rosenthal')
# (47, 'THE CALYPSO MYSTERY: A SciFi Adventure (The Ancient Secrets Book 5)', 'T.S. Falk')
# (48, 'Primeval Origins : Paths of Anguish (Epic Fantasy / SciFi Book Series 1)', 'B.A. Vonsik')
# (49, 'ICE: A SciFi Adventure', 'T.S. Falk')
# (50, 'THE KEEPERS OF SECRETS: A SciFi Adventure (The Ancient Secrets Book 6)', 'T.S. Falk')
# (51, "Nova's Blade: A Young Adult Dystopian", 'Will Scifi')
# (52, "Nova's Blade: A Young Adult Dystopian Cyberpunk", 'Will Scifi')
# (53, 'The Arx: A Thriller/Scifi novel', 'Jay Allan Storey')
# (54, 'Defenders of the Rim: Beginnings (A Far Future SciFi Thriller, #1)', 'Randal Sloan')
# (55, 'The Maker War: A scifi action-adventure novel for the whole family', 'D.M.C. Shaw')
# (56, 'THE APOCALYPSE SEQUENCE I: A SciFi Adventure (The Ancient Secrets Book 7)', 'T.S. Falk')
# (57, 'The Adventures of Kirk Rogers: Inside the Moon (The Kirk Rogers Series: Scifi • Action • Comedy Book 1)', 'C.J. Boyle')
# (58, '2022 SciFi Anthology (The Science Fiction Novelists, #2)', 'E.J. Runyon')
# (59, 'SciFi & Fantasy: Five Movie Length Tales From Aisle Seat Books', 'S.A. Gibson')
# (60, 'Election Day: A Horrifying Thriller', 'Claudia Blood')
# (61, 'Starfighter Rising: An Epic SciFi Adventure (Starfighter Rising Series Book 1)', 'Daniel Seegmiller')
# (62, "Stranded with the Alien: A SciFi Fated Mates Romance (Antasun's Alien Castaways Book 1)", 'Roxy Nash')
# (63, 'Zero: A prequel to the humorous scifi series', 'Simon Haynes')
# (64, '2023 SciFi Anthology (The Science Fiction Novelists, #3)', 'S.A. Gibson')
# (65, 'Rescuing Red (SciFi Fairytale Fusions #1)', 'David Booker')
# (66, 'Claimed by Brothers: A Scifi Alien Romance (Over the Top Galactic Heroes Book 1)', 'Philip Cahill')
# (67, 'Worlds of Wonder: Collected SciFi Short Stories', 'Leann Ryans')
# (68, 'Alien Song: A Royal Alien Romance (Scifi Alien Human Romance, #1)', 'V.T. Bonds')
# (69, "The Alien Prince's Captive (Scifi Alien Romance)", 'Kai Lesy')
# (70, 'Soren: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 1)', 'Tony Teora')
# (71, 'Solar King: Uniting the Twelve Zodiacs - Taurus', 'Marco  Frazetta')
# (72, 'The First Men in the Moon', 'H.G. Wells')
# (73, 'Loved Cyborg: A SciFi Cyborg Romance (Bound by Her Book 2)', 'Nellie C. Lind')
# (74, 'THE APOCALYPSE SEQUENCE II: A SciFi Adventure (The Ancient Secrets Book 8)', 'T.S. Falk')
# (75, 'Taken to Sky: A SciFi Alien Romance (Xiveri Mates Book 9)', 'Elizabeth  Stephens')
# (76, 'Shadow Corps Boxset 1-4: A Military SciFi Series', 'Justin Sloan')
# (77, 'Bride to the Brutal Beast: A SciFi Romance (Galactic Matchmakers Book 1)', 'Athena Storm')
# (78, "Warhead: Origins: A Scifi Haremlit Fantasy Series (The Brother's Code Book 1)", 'Troy Maverick')
# (79, 'PULSERIDER: A SciFi Adventure', 'Lou Schreiber')
# (80, 'Rathgar: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 2)', 'Taylor Neptune')
# (81, 'Eldorado: A Dystopian/Scifi Novel', 'Jay Allan Storey')
# (82, 'Defenders of the Rim: Badlands (A Far Future SciFi Thriller, #2)', 'Randal Sloan')
# (83, 'Spring Into SciFi : 2023 Edition', 'Andrew M. Ferrell')
# (84, 'Abducted By The Warrior Prince: A SciFi Alien Romance (Lunarian Warriors Book 1)', 'Karl El-Koura')
# (85, "Sucaen: A SciFi Alien Warrior Romance (Ka'atari Warriors Book 5)", 'Alex Minns')
# (86, 'Spring Into SciFi: 2022 Edition', 'Roxie Ray')
# (87, 'Terminus Project: Mars', 'Kenzie Kelly')
# (88, "Alien Hunter's Prey: A SciFi Romance (Mates of the Baktu Book 1)", 'Greg Eccleston')
# (89, 'Retribution (Sector 64 #2)', 'Alex Minns')
# (90, 'Brutal Alien Beasts: A Collection of Scifi Romances', 'Mark Bilsborough')
# (91, 'The Ancient Code: A SciFi Adventure (The Ancient Secrets, #1)', 'T.S. Falk')
# (92, 'THE EXTINCTION THREAT: A SciFi Adventure (The Ancient Secrets, #2)', 'T.S. Falk')
# (93, 'RELIC: A SciFi Adventure', 'T.S. Falk')
# (94, 'THE ANCESTOR TRAP: A SciFi Adventure (The Ancient Secrets, #3)', 'T.S. Falk')
# (95, 'THE MISSING LINK: A SciFi Adventure (The Ancient Secrets, #4)', 'T.S. Falk')
# (96, 'Free Science Fiction Books On Kindle: Linked List of over 350 Free SciFi  Classic Stories And Early Fantasy Novels', 'Morris Rosenthal')
# (97, 'THE CALYPSO MYSTERY: A SciFi Adventure (The Ancient Secrets Book 5)', 'T.S. Falk')
# (98, 'Primeval Origins : Paths of Anguish (Epic Fantasy / SciFi Book Series 1)', 'B.A. Vonsik')
# (99, 'ICE: A SciFi Adventure', 'T.S. Falk')
# (100, 'THE KEEPERS OF SECRETS: A SciFi Adventure (The Ancient Secrets Book 6)', 'T.S. Falk')
# (101, "Nova's Blade: A Young Adult Dystopian Cyberpunk", 'Will Scifi')
# (102, "Nova's Blade: A Young Adult Dystopian", 'Will Scifi')
# (103, 'The Arx: A Thriller/Scifi novel', 'Jay Allan Storey')
# (104, 'Defenders of the Rim: Beginnings (A Far Future SciFi Thriller, #1)', 'Randal Sloan')
# (105, 'The Maker War: A scifi action-adventure novel for the whole family', 'D.M.C. Shaw')
# (106, 'The Adventures of Kirk Rogers: Inside the Moon (The Kirk Rogers Series: Scifi • Action • Comedy Book 1)', 'C.J. Boyle')
# (107, 'THE APOCALYPSE SEQUENCE I: A SciFi Adventure (The Ancient Secrets Book 7)', 'T.S. Falk')
# (108, '2022 SciFi Anthology (The Science Fiction Novelists, #2)', 'E.J. Runyon')
# (109, 'Election Day: A Horrifying Thriller', 'S.A. Gibson')
# (110, "Stranded with the Alien: A SciFi Fated Mates Romance (Antasun's Alien Castaways Book 1)", 'Claudia Blood')
# (111, 'Starfighter Rising: An Epic SciFi Adventure (Starfighter Rising Series Book 1)', 'Daniel Seegmiller')
# (112, "Stranded with the Alien: A SciFi Fated Mates Romance (Antasun's Alien Castaways Book 1)", 'Roxy Nash')
# (113, 'Zero: A prequel to the humorous scifi series', 'Simon Haynes')
# (114, '2023 SciFi Anthology (The Science Fiction Novelists, #3)', 'S.A. Gibson')
# (115, 'Rescuing Red (SciFi Fairytale Fusions #1)', 'David Booker')
# (116, 'Alien Song: A Royal Alien Romance (Scifi Alien Human Romance, #1)', 'Philip Cahill')
# (117, 'Claimed by Brothers: A Scifi Alien Romance (Over the Top Galactic Heroes Book 1)', 'Leann Ryans')
# (118, "The Alien Prince's Captive (Scifi Alien Romance)", 'V.T. Bonds')
# (119, 'Worlds of Wonder: Collected SciFi Short Stories', 'Deiri Di')
# (120, 'Soren: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 1)', 'Kai Lesy')
# (121, 'The First Men in the Moon', 'H.G. Wells')
# (122, 'Loved Cyborg: A SciFi Cyborg Romance (Bound by Her Book 2)', 'Nellie C. Lind')
# (123, 'Solar King: Uniting the Twelve Zodiacs - Taurus', 'Marco  Frazetta')
# (124, 'Taken to Sky: A SciFi Alien Romance (Xiveri Mates Book 9)', 'Elizabeth  Stephens')
# (125, 'Shadow Corps Boxset 1-4: A Military SciFi Series', 'Justin Sloan')
# (126, 'Bride to the Brutal Beast: A SciFi Romance (Galactic Matchmakers Book 1)', 'Athena Storm')
# (127, "Warhead: Origins: A Scifi Haremlit Fantasy Series (The Brother's Code Book 1)", 'Troy Maverick')
# (128, 'THE APOCALYPSE SEQUENCE II: A SciFi Adventure (The Ancient Secrets Book 8)', 'T.S. Falk')
# (129, 'Eldorado: A Dystopian/Scifi Novel', 'Jay Allan Storey')
# (130, 'Defenders of the Rim: Badlands (A Far Future SciFi Thriller, #2)', 'Randal Sloan')
# (131, 'PULSERIDER: A SciFi Adventure', 'Lou Schreiber')
# (132, 'Rathgar: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 2)', 'Taylor Neptune')
# (133, "Sucaen: A SciFi Alien Warrior Romance (Ka'atari Warriors Book 5)", 'Jasper Thorne')
# (134, 'Spring Into SciFi : 2023 Edition', 'Kenzie Kelly')
# (135, 'Abducted By The Warrior Prince: A SciFi Alien Romance (Lunarian Warriors Book 1)', 'Andrew M. Ferrell')
# (136, 'Spring Into SciFi: 2022 Edition', 'Karl El-Koura')
# (137, 'Retribution (Sector 64 #2)', 'Alex Minns')
# (138, 'Terminus Project: Mars', 'Roxie Ray')
# (139, 'Celestial Mates Complete Series Box Set (Books 6-10) (Alien SciFi Romance)', 'Greg Eccleston')
# (140, "Alien Hunter's Prey: A SciFi Romance (Mates of the Baktu Book 1)", 'Alex Minns')
# (141, 'The Ancient Code: A SciFi Adventure (The Ancient Secrets, #1)', 'T.S. Falk')
# (142, 'THE EXTINCTION THREAT: A SciFi Adventure (The Ancient Secrets, #2)', 'T.S. Falk')
# (143, 'RELIC: A SciFi Adventure', 'T.S. Falk')
# (144, 'THE ANCESTOR TRAP: A SciFi Adventure (The Ancient Secrets, #3)', 'T.S. Falk')
# (145, 'THE MISSING LINK: A SciFi Adventure (The Ancient Secrets, #4)', 'T.S. Falk')
# (146, 'Free Science Fiction Books On Kindle: Linked List of over 350 Free SciFi  Classic Stories And Early Fantasy Novels', 'Morris Rosenthal')
# (147, 'THE CALYPSO MYSTERY: A SciFi Adventure (The Ancient Secrets Book 5)', 'T.S. Falk')
# (148, 'Primeval Origins : Paths of Anguish (Epic Fantasy / SciFi Book Series 1)', 'B.A. Vonsik')
# (149, 'ICE: A SciFi Adventure', 'T.S. Falk')
# (150, 'THE KEEPERS OF SECRETS: A SciFi Adventure (The Ancient Secrets Book 6)', 'T.S. Falk')
# (151, "Nova's Blade: A Young Adult Dystopian Cyberpunk", 'Will Scifi')
# (152, "Nova's Blade: A Young Adult Dystopian", 'Will Scifi')
# (153, 'The Arx: A Thriller/Scifi novel', 'Jay Allan Storey')
# (154, 'Defenders of the Rim: Beginnings (A Far Future SciFi Thriller, #1)', 'Randal Sloan')
# (155, 'The Maker War: A scifi action-adventure novel for the whole family', 'D.M.C. Shaw')
# (156, 'The Adventures of Kirk Rogers: Inside the Moon (The Kirk Rogers Series: Scifi • Action • Comedy Book 1)', 'C.J. Boyle')
# (157, 'THE APOCALYPSE SEQUENCE I: A SciFi Adventure (The Ancient Secrets Book 7)', 'T.S. Falk')
# (158, '2022 SciFi Anthology (The Science Fiction Novelists, #2)', 'E.J. Runyon')
# (159, 'Election Day: A Horrifying Thriller', 'S.A. Gibson')
# (160, "Stranded with the Alien: A SciFi Fated Mates Romance (Antasun's Alien Castaways Book 1)", 'Claudia Blood')
# (161, "Stranded with the Alien: A SciFi Fated Mates Romance (Antasun's Alien Castaways Book 1)", 'Roxy Nash')
# (162, 'Starfighter Rising: An Epic SciFi Adventure (Starfighter Rising Series Book 1)', 'Daniel Seegmiller')
# (163, 'Zero: A prequel to the humorous scifi series', 'Simon Haynes')
# (164, '2023 SciFi Anthology (The Science Fiction Novelists, #3)', 'S.A. Gibson')
# (165, 'Rescuing Red (SciFi Fairytale Fusions #1)', 'David Booker')
# (166, "The Alien Prince's Captive (Scifi Alien Romance)", 'Philip Cahill')
# (167, 'Soren: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 1)', 'Leann Ryans')
# (168, 'Claimed by Brothers: A Scifi Alien Romance (Over the Top Galactic Heroes Book 1)', 'V.T. Bonds')
# (169, 'Worlds of Wonder: Collected SciFi Short Stories', 'Luna Hunter')
# (170, 'Alien Song: A Royal Alien Romance (Scifi Alien Human Romance, #1)', 'Taylor Neptune')
# (171, 'The First Men in the Moon', 'H.G. Wells')
# (172, 'Loved Cyborg: A SciFi Cyborg Romance (Bound by Her Book 2)', 'Nellie C. Lind')
# (173, 'Solar King: Uniting the Twelve Zodiacs - Taurus', 'Marco  Frazetta')
# (174, 'Taken to Sky: A SciFi Alien Romance (Xiveri Mates Book 9)', 'Elizabeth  Stephens')
# (175, 'Shadow Corps Boxset 1-4: A Military SciFi Series', 'Justin Sloan')
# (176, 'Bride to the Brutal Beast: A SciFi Romance (Galactic Matchmakers Book 1)', 'Athena Storm')
# (177, "Warhead: Origins: A Scifi Haremlit Fantasy Series (The Brother's Code Book 1)", 'Troy Maverick')
# (178, 'THE APOCALYPSE SEQUENCE II: A SciFi Adventure (The Ancient Secrets Book 8)', 'T.S. Falk')
# (179, 'Eldorado: A Dystopian/Scifi Novel', 'Jay Allan Storey')
# (180, 'Defenders of the Rim: Badlands (A Far Future SciFi Thriller, #2)', 'Randal Sloan')
# (181, 'PULSERIDER: A SciFi Adventure', 'Lou Schreiber')
# (182, 'Rathgar: Scifi Alien Romance (Intergalactic Surrogacy Agency Book 2)', 'Taylor Neptune')
# (183, "Sucaen: A SciFi Alien Warrior Romance (Ka'atari Warriors Book 5)", 'Jasper Thorne')
# (184, 'Spring Into SciFi : 2023 Edition', 'Kenzie Kelly')
# (185, 'Abducted By The Warrior Prince: A SciFi Alien Romance (Lunarian Warriors Book 1)', 'Andrew M. Ferrell')
# (186, 'Spring Into SciFi: 2022 Edition', 'Karl El-Koura')
# (187, 'Retribution (Sector 64 #2)', 'Alex Minns')
# (188, 'Terminus Project: Mars', 'Roxie Ray')
# (189, 'Celestial Mates Complete Series Box Set (Books 6-10) (Alien SciFi Romance)', 'Greg Eccleston')
# (190, "Alien Hunter's Prey: A SciFi Romance (Mates of the Baktu Book 1)", 'Alex Minns')
